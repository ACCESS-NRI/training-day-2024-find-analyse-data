# %% [markdown]
# # Introduction to the ACCESS-NRI Intake catalog
#
# **Aims**: This tutorial will introduce the ACCESS-NRI Intake catalog a show you how to use it to find and load model data for analysis
#
# **Project membership requirements**:
#
#  - If using the `xp65` conda environment: `xp65`, `dk92`, `fs38` and `p73`
#  - If using the `hh5` conda environment: as above but also `hh5`
#
#
# The ACCESS-NRI Intake Catalog is curated by ACCESS-NRI with further information on its <a href="https://access-nri-intake-catalog.readthedocs.io/en/latest/index.html" target="_blank">documentation website</a> and <a href="https://access-hive.org.au/model_evaluation/model_evaluation_model_catalogs" target="_blank">this ACCESS-Hive page</a>.
#
# ----

# %% [markdown]
# # The motivation

# %% [markdown]
# Data products (whether model output or observation based) are split across a collection of projects, in various formats and sometimes in a large number of files.
#
# This can be tricky, if the output is organised different for different model output. For example:
# - ACCESS CMIP6 output is in `/g/data/fs38` and locally replicated CMIP6 output from other modelling centers is in `/g/data/oi10`
# - Some model output (e.g. CICE) contains many variables in one history file, so its not clear what variables are available until opening the file.
#
# A catalog provides functionality for searching, discovering and loading data. Data discovery is improved by facilitating a variety of search terms, including by name, model, realm (e.g. model component), data frequency, variable name and variable standard names (for CF-compliant output, these should be consistent across models.
#
# In our case, the catalog is built using the [Intake-ESM](https://intake-esm.readthedocs.io/) framework, with python code added to capture ACCESS model output formats and to collate a set of common model output into one catalog.

# %% [markdown]
# # Using the catalog

# %% [markdown]
# The general process for using the catalog is as follows:
#
# 1. Search the ACCESS-NRI catalog for data products that are of interest to you.
#
#    <img src="../assets/catalog-example.png" alt="Example intake-esm datastore" width=800/><br />
# 3. Open the Intake-ESM datastore(s) for the product(s) of interest. (N.B. assets = files with history/diagnostic output, dataset = output with consistent coordinates and frequency, which can be concatenated over time)
#
#    <img src="../assets/datastore-example.png" alt="Example intake-esm datastore" width=600/><br />
# 5. Search the Intake-ESM datastore(s) for the datasets that are of interest to you.
# 6. Open the datasets of interest as xarray Dataset(s).
#
#    <img src="../assets/dataset-example.png" alt="Example xarray dataset" width=800/></td>
# 8. Perform some analysis on the xarray Dataset(s).

# %% [markdown]
# This process is also illustrated in the schematic below. Pink text indicates the methods used to perform each task.

# %% [markdown]
# <img src="../assets/catalog_flow.svg" alt="Diagram of steps from having a catalog to getting an analysis ready dataset" width=600/>

# %% [markdown]
# If a user knows in advance the name of the product(s) they are after, then the first two steps above are not needed. Instead, those Intake-ESM datastores can be easily retreived directly from the catalog as demonstrated later on.

# %% [markdown]
# # Opening the catalog

# %% [markdown]
# We'll now go through the steps in more detail. First we open the catalog

# %%
import intake

catalog = intake.cat.access_nri

# %% [markdown]
# With that, we can now use `catalog` to search and load ~3 PB of data without having to know where the data is or how it's structured.
#
# The catalog includes a wide variety of climate data products. The "name" column gives the name of the data product and the other columns provide additional metadata associated with each product. As we'll demonstrate below, you can search on metadata in these columns to filter for data products that may be of interest to you. Scroll through the products below and get an idea for what each product is by looking at the entry in the description column.

# %%
catalog
# Out:
# <p><strong>access_nri catalog with 94 source(s) across 2268 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, 3mon, 3hr, 1day, fx}</td>
#       <td>{melt, buoyfreq2_wt, tau_x, temp_submeso, dxu, uarea, sfc_salt_flux_ice, salt, total_ocean_melt, river, alidf_ai_m, HTN, total_ocean_hflux_prec, strairy_m, total_ocean_calving, total_net_sfc_heati...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, buoyfreq2_wt, tau_x, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, total_ocean_melt, river, surface_temp_min, alidf_ai_m, HTN, total_ocean_hflux_prec, mld_max, strairy_m, total...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle2</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 2 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, buoyfreq2_wt, tau_x, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, surface_pot_temp_max, total_ocean_melt, river, divu, surface_temp_min, alidf_ai_m, surface_temp_max, HTN, tot...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle3</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 3 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, buoyfreq2_wt, tau_x, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, surface_pot_temp_max, total_ocean_melt, river, divu, alidf_ai_m, HTN, total_ocean_hflux_prec, mld_max, strair...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 4 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, 3hr, 6hr, 1day, fx}</td>
#       <td>{buoyfreq2_wt, river, alidf_ai_m, total_ocean_hflux_prec, caco3_xflux_adv, total_net_sfc_heating, surface_pot_temp_min, alvdr_ai, fsalt_m, fN_ai_m, caco3_yflux_adv, adic_xflux_adv, uvel_m, Sinz_m,...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4_jra55v150_extension</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Extensions of cycle 4 of 0.1 degree ACCESS-OM2 + WOMBAT BGC global model  configuration with JRA55-do v1.5.0 and v1.5.0.1 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{subhr, 1day, 1mon, fx}</td>
#       <td>{melt, buoyfreq2_wt, tau_x, dxu, algal_N, uarea, surface_fe, sfc_salt_flux_ice, surface_zoo, temp_xflux_adv_int_z, salt, surface_pot_temp_max, total_ocean_melt, stf03, surface_phy, river, divu, al...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v150_iaf_cycle1</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.5.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, tau_x, dxu, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, river, mld_max, evap_heat, average_T1, temp, age_global, temp_int_rhodz, geolon_c, geolat_c, fprec_melt_heat, dzt, hi_m, ht, dyt, ...</td>
#     </tr>
#     <tr>
#       <th>025deg_era5_iaf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with ERA5 interannual\nforcing (1980-2021)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, albice_m, strcory_m, tau_x, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, surface_pot_temp_max, total_ocean_melt, river, rain_ai_m, strcorx_m, temp_yflux_gm_int_z, alidf_ai_m, ...</td>
#     </tr>
#     <tr>
#       <th>025deg_era5_ryf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with ERA5 RYF9091 repeat\nyear forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, albice_m, strcory_m, tau_x, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, surface_pot_temp_max, total_ocean_melt, river, rain_ai_m, strcorx_m, temp_yflux_gm_int_z, alidf_ai_m, ...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_era5comparison</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with JRA55-do v1.5.0\ninterannual forcing (1980-2019)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, albice_m, strcory_m, tau_x, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, surface_pot_temp_max, total_ocean_melt, river, rain_ai_m, strcorx_m, temp_yflux_gm_int_z, HTN, total_o...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle1</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1958-2019)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1yr, 1mon, fx}</td>
#       <td>{melt, albice_m, buoyfreq2_wt, strcory_m, tx_trans_gm, tau_x, temp_submeso, pbot_adjust, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, salt_nonlocal_KPP, surface_pot_temp_max, total_o...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle2</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1958-2019)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1yr, 1mon, fx}</td>
#       <td>{melt, albice_m, buoyfreq2_wt, strcory_m, tx_trans_gm, tau_x, temp_submeso, pbot_adjust, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, salt_nonlocal_KPP, surface_pot_temp_max, total_o...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle3</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 3/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1958-2019)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1yr, 1mon, fx}</td>
#       <td>{melt, albice_m, buoyfreq2_wt, strcory_m, tx_trans_gm, tau_x, temp_submeso, pbot_adjust, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, salt_nonlocal_KPP, surface_pot_temp_max, total_o...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle4</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 4/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1958-2019)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1yr, 1mon, fx}</td>
#       <td>{melt, albice_m, buoyfreq2_wt, strcory_m, tx_trans_gm, tau_x, temp_submeso, pbot_adjust, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, salt_nonlocal_KPP, surface_pot_temp_max, total_o...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle5</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 5/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1

# %% [markdown]
# Each entry (row) in the catalog describes a data product comprising many datasets spread across many files (a "dataset" here is a set of files that can be readily opened and combined for analysis using xarray - more on this later). For example, in a given ACCESS-CM2 product, there may be a dataset of ocean variables at monthly frequency, atmospheric variables at monthly frequency etc. Each entry in the catalog has a corresponding Intake-ESM datastore that can be used to filter for datasets of interest based on metadata in the datastore and then to open those datasets using xarray.

# %% [markdown]
# # Catalog filtering and data discovery

# %% [markdown]
# We can search on the columns in the ACCESS-NRI catalog. For example, we could search for all products that use the model `ACCESS-OM2`. The `search` method returns another catalog object with entries that satisfy our search criteria.

# %%
catalog_filtered_example = catalog.search(model="ACCESS-OM2")
catalog_filtered_example
# Out:
# <p><strong>Intake dataframe catalog with 76 source(s) across 334 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, 3mon, 3hr, 1day, fx}</td>
#       <td>{melt, buoyfreq2_wt, tau_x, temp_submeso, dxu, uarea, sfc_salt_flux_ice, salt, total_ocean_melt, river, alidf_ai_m, HTN, total_ocean_hflux_prec, strairy_m, total_ocean_calving, total_net_sfc_heati...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, buoyfreq2_wt, tau_x, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, total_ocean_melt, river, surface_temp_min, alidf_ai_m, HTN, total_ocean_hflux_prec, mld_max, strairy_m, total...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle2</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 2 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, buoyfreq2_wt, tau_x, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, surface_pot_temp_max, total_ocean_melt, river, divu, surface_temp_min, alidf_ai_m, surface_temp_max, HTN, tot...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle3</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 3 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, buoyfreq2_wt, tau_x, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, surface_pot_temp_max, total_ocean_melt, river, divu, alidf_ai_m, HTN, total_ocean_hflux_prec, mld_max, strair...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 4 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1mon, 3hr, 6hr, 1day, fx}</td>
#       <td>{buoyfreq2_wt, river, alidf_ai_m, total_ocean_hflux_prec, caco3_xflux_adv, total_net_sfc_heating, surface_pot_temp_min, alvdr_ai, fsalt_m, fN_ai_m, caco3_yflux_adv, adic_xflux_adv, uvel_m, Sinz_m,...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4_jra55v150_extension</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Extensions of cycle 4 of 0.1 degree ACCESS-OM2 + WOMBAT BGC global model  configuration with JRA55-do v1.5.0 and v1.5.0.1 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{subhr, 1day, 1mon, fx}</td>
#       <td>{melt, buoyfreq2_wt, tau_x, dxu, algal_N, uarea, surface_fe, sfc_salt_flux_ice, surface_zoo, temp_xflux_adv_int_z, salt, surface_pot_temp_max, total_ocean_melt, stf03, surface_phy, river, divu, al...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v150_iaf_cycle1</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.5.0 OMIP2 interannual forcing}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, tau_x, dxu, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, river, mld_max, evap_heat, average_T1, temp, age_global, temp_int_rhodz, geolon_c, geolat_c, fprec_melt_heat, dzt, hi_m, ht, dyt, ...</td>
#     </tr>
#     <tr>
#       <th>025deg_era5_iaf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with ERA5 interannual\nforcing (1980-2021)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, albice_m, strcory_m, tau_x, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, surface_pot_temp_max, total_ocean_melt, river, rain_ai_m, strcorx_m, temp_yflux_gm_int_z, alidf_ai_m, ...</td>
#     </tr>
#     <tr>
#       <th>025deg_era5_ryf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with ERA5 RYF9091 repeat\nyear forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, albice_m, strcory_m, tau_x, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, surface_pot_temp_max, total_ocean_melt, river, rain_ai_m, strcorx_m, temp_yflux_gm_int_z, alidf_ai_m, ...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_era5comparison</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with JRA55-do v1.5.0\ninterannual forcing (1980-2019)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{melt, albice_m, strcory_m, tau_x, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, surface_pot_temp_max, total_ocean_melt, river, rain_ai_m, strcorx_m, temp_yflux_gm_int_z, HTN, total_o...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle1</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1958-2019)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1yr, 1mon, fx}</td>
#       <td>{melt, albice_m, buoyfreq2_wt, strcory_m, tx_trans_gm, tau_x, temp_submeso, pbot_adjust, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, salt_nonlocal_KPP, surface_pot_temp_max, total_o...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle2</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1958-2019)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1yr, 1mon, fx}</td>
#       <td>{melt, albice_m, buoyfreq2_wt, strcory_m, tx_trans_gm, tau_x, temp_submeso, pbot_adjust, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, salt_nonlocal_KPP, surface_pot_temp_max, total_o...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle3</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 3/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1958-2019)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1yr, 1mon, fx}</td>
#       <td>{melt, albice_m, buoyfreq2_wt, strcory_m, tx_trans_gm, tau_x, temp_submeso, pbot_adjust, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, salt_nonlocal_KPP, surface_pot_temp_max, total_o...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle4</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 4/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1958-2019)}</td>
#       <td>{ocean, seaIce}</td>
#       <td>{1day, 1yr, 1mon, fx}</td>
#       <td>{melt, albice_m, buoyfreq2_wt, strcory_m, tx_trans_gm, tau_x, temp_submeso, pbot_adjust, dxu, uarea, sfc_salt_flux_ice, temp_xflux_adv_int_z, salt, salt_nonlocal_KPP, surface_pot_temp_max, total_o...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle5</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 5/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forci

# %% [markdown]
# We can also combine queries in a search. For example, below we search for all products that use the model `ACCESS-OM2` and contain the variable `wdet100` at daily frequency.

# %%
catalog.search(model="ACCESS-OM2", frequency="1day", variable="wdet100")
# Out:
# <p><strong>Intake dataframe catalog with 2 source(s) across 2 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 4 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1day}</td>
#       <td>{wdet100}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4_jra55v150_extension</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Extensions of cycle 4 of 0.1 degree ACCESS-OM2 + WOMBAT BGC global model  configuration with JRA55-do v1.5.0 and v1.5.0.1 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1day}</td>
#       <td>{wdet100}</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %% [markdown]
# We can also use regex strings in our searches. For example, we could relax our query on variable to look for any variables starting with the letter `"w"`.

# %%
catalog.search(model="ACCESS-OM2", frequency="1day", variable="w.*")
# Out:
# <p><strong>Intake dataframe catalog with 4 source(s) across 4 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{ocean}</td>
#       <td>{1day}</td>
#       <td>{wt}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1day}</td>
#       <td>{wt}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 4 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1day}</td>
#       <td>{wdet100}</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4_jra55v150_extension</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Extensions of cycle 4 of 0.1 degree ACCESS-OM2 + WOMBAT BGC global model  configuration with JRA55-do v1.5.0 and v1.5.0.1 interannual forcing}</td>
#       <td>{ocean}</td>
#       <td>{1day}</td>
#       <td>{wdet100}</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %% [markdown]
# Note, metadata in the `realm` and `frequency` columns of the ACCESS-NRI catalog follow a standard vocabulary that is very similar to CMIP6 (but slightly more general):
#
#  - `realm` may be one of:
#    - `aerosol`,
#    - `atmos`,
#    - `atmosChem`,
#    - `land`,
#    - `landIce`,
#    - `none`,
#    - `ocean`,
#    - `ocnBgchem`,
#    - `seaIce`,
#    - `unknown`
#  - `frequency` may be one of (where `<int>` is an integer):
#    - `fx`
#    - `subhr`
#    - `<int>hr`
#    - `<int>day`
#    - `<int>mon`
#    - `<int>yr`
#    - `<int>dec`
#
# Some attempt has been made to use consistent model names in the `model` column (e.g. always use "ACCESS-OM2" for ACCESS-OM2), but model naming is not enforced. The variable names in the `variable` column are whatever they're called in the associated data product.

# %% [markdown]
# Note that the ACCESS-NRI Intake Catalog contains the data products locally stored and replicated from CMIP6 results, and other locally produced model output. Sometimes these names can be confusing, for example data from models named 'ACCESS-OM2-025' contains results submitted to the Ocean MIP at a nominal 0.25 degree resolution using the CMOR standard variable. Data from models named 'ACCESS-OM2' also contains results at a nominal 0.25 degree resolution, however they used the model's chosen names for variables.

# %% [markdown]
# You can find the valid values for a field by using the "dataframe" view to select the field, and type it as a set to return the unique values.

# %%
set(catalog.search(model="ACCESS-*").df.model)
# Out:
# {('ACCESS-CM2',),
#  ('ACCESS-ESM1-5',),
#  ('ACCESS-OM2',),
#  ('ACCESS-OM2-025',),
#  ('ACCESS1-0',),
#  ('ACCESS1-3',)}

# %% [markdown]
# # Loading Intake sources

# %% [markdown]
# Each entry in the catalog has an associated Intake-ESM datastore that keeps track of all the files in that product and how they fit together into datasets. There are three ways to open Intake-ESM datastores from the catalog, depending on your use case:

# %% [markdown]
# ## 1. You know the name of the product you want
#
# In this case, you can open the Intake-ESM datastore for that product directly as an attribute or key. For example

# %%
datastore_example = catalog.by647

# Or

datastore_example = catalog["by647"]

# %%
datastore_example
# Out:
# <p><strong>by647 catalog with 7 dataset(s) from 1350 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>path</th>
#       <td>1350</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>652</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>member</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>variable_long_name</th>
#       <td>643</td>
#     </tr>
#     <tr>
#       <th>variable_standard_name</th>
#       <td>135</td>
#     </tr>
#     <tr>
#       <th>variable_cell_methods</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>variable_units</th>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>filename</th>
#       <td>750</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# ## 2. You've filtered the catalog for the products you want and there are multiple remaining
#
# In this case, you can open the Intake-ESM datastores for all entries in a catalog using the `to_source_dict` method. For example

# %%
datastore_dict_example = catalog.search(model="ACCESS-OM2", frequency="1day", variable="wdet100").to_source_dict()

# %%
datastore_dict_example
# Out:
# {'01deg_jra55v140_iaf_cycle4_jra55v150_extension': <01deg_jra55v140_iaf_cycle4_jra55v150_extension catalog with 198 dataset(s) from 14273 asset(s)>,
#  '01deg_jra55v140_iaf_cycle4': <01deg_jra55v140_iaf_cycle4 catalog with 206 dataset(s) from 131730 asset(s)>}

# %% [markdown]
# ## 3. You've filtered the catalog for the products you want and there's only one remaining
#
# In this case, you can open the Intake-ESM datastore for the remaining product using the `to_source` method (note you could also use `to_source_dict` which would return a dictionary containing the Intake-ESM datastore, rather than the datastore itself). For example

# %%
catalog
# Out:
# <p><strong>access_nri catalog with 94 source(s) across 2268 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx, 1day, 3mon, 3hr}</td>
#       <td>{tau_x, vvel_m, NCAT, frz_onset_m, sfc_salt_flux_coupler, geolat_t, total_ocean_runoff_heat, tx_trans_int_z, HTN, sst_m, surface_salt, dyu, tx_trans, uocn_m, temp_rivermix, passive_ross, eta_t, to...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{tau_x, vvel_m, NCAT, surface_temp_min, sfc_salt_flux_coupler, total_ocean_runoff_heat, tx_trans_int_z, geolat_t, HTN, surface_salt, dyu, tx_trans, total_ocean_salt, area_t, uvel, total_ocean_rive...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle2</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 2 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{sea_level_max, tau_x, meltt, vvel_m, NCAT, surface_temp_min, sfc_salt_flux_coupler, total_ocean_runoff_heat, tx_trans_int_z, geolat_t, HTN, surface_salt, dyu, tx_trans, surface_pot_temp, bottom_t...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle3</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 3 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{sea_level_max, tau_x, meltt, vvel_m, NCAT, sfc_salt_flux_coupler, geolat_t, total_ocean_runoff_heat, tx_trans_int_z, HTN, surface_salt, dyu, tx_trans, surface_pot_temp, bottom_temp_max, passive_r...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 4 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 OMIP2 interannual forcing}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx, 1day, 6hr, 3hr}</td>
#       <td>{dardg2dt, fswabs_ai_m, tau_x, skl_Nit, dyu, bottom_temp_max, total_ocean_salt, ml_Nit_m, congel, temp_surface_ave, time_bounds, total_ocean_evap, pbot_t, npp_int100, total_ocean_hflux_evap, phy_i...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v140_iaf_cycle4_jra55v150_extension</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Extensions of cycle 4 of 0.1 degree ACCESS-OM2 + WOMBAT BGC global model  configuration with JRA55-do v1.5.0 and v1.5.0.1 interannual forcing}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, subhr, 1mon, fx}</td>
#       <td>{radbio_int100, dardg2dt, caco3_yflux_adv, fswabs_ai_m, sea_level_max, tau_x, meltt, vvel_m, skl_Nit_m, dic, NCAT, no3_intmld, skl_Nit, sfc_salt_flux_coupler, geolat_t, total_ocean_runoff_heat, di...</td>
#     </tr>
#     <tr>
#       <th>01deg_jra55v150_iaf_cycle1</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1 of 0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.5.0 OMIP2 interannual forcing}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{tau_x, sfc_salt_flux_coupler, geolat_t, tx_trans_int_z, surface_salt, dyu, tx_trans, surface_pot_temp, time_bnds, eta_t, area_t, melt, u, time_bounds, bmf_u, sens_heat, pbot_t, ULON, runoff, evap...</td>
#     </tr>
#     <tr>
#       <th>025deg_era5_iaf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with ERA5 interannual\nforcing (1980-2021)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{fswabs_ai_m, sea_level_max, temp_xflux_submeso_int_z, tau_x, vvel_m, fswdn_m, NCAT, rain_ai_m, sfc_salt_flux_coupler, geolat_t, total_ocean_runoff_heat, tx_trans_int_z, HTN, surface_salt, dyu, st...</td>
#     </tr>
#     <tr>
#       <th>025deg_era5_ryf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with ERA5 RYF9091 repeat\nyear forcing (May 1990 to Apr 1991)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{fswabs_ai_m, temp_xflux_submeso_int_z, tau_x, vvel_m, fswdn_m, NCAT, rain_ai_m, sfc_salt_flux_coupler, geolat_t, total_ocean_runoff_heat, tx_trans_int_z, HTN, surface_salt, dyu, strinty_m, surfac...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_era5comparison</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.25 degree ACCESS-OM2 global model configuration with JRA55-do v1.5.0\ninterannual forcing (1980-2019)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{fswabs_ai_m, sea_level_max, temp_xflux_submeso_int_z, tau_x, vvel_m, fswdn_m, NCAT, rain_ai_m, sfc_salt_flux_coupler, geolat_t, total_ocean_runoff_heat, tx_trans_int_z, HTN, surface_salt, dyu, st...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle1</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1958-2019)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, 1yr, fx}</td>
#       <td>{psiu, sfc_hflux_from_water_prec, fswabs_ai_m, sea_level_max, temp_xflux_submeso_int_z, tau_x, meltt, vvel_m, fswdn_m, tx_trans_rho_gm, NCAT, rain_ai_m, sfc_salt_flux_coupler, geolat_t, total_ocea...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle2</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 1/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1958-2019)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, 1yr, fx}</td>
#       <td>{psiu, sfc_hflux_from_water_prec, fswabs_ai_m, sea_level_max, temp_xflux_submeso_int_z, tau_x, meltt, vvel_m, fswdn_m, tx_trans_rho_gm, NCAT, rain_ai_m, sfc_salt_flux_coupler, geolat_t, total_ocea...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle3</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 3/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1958-2019)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, 1yr, fx}</td>
#       <td>{psiu, sfc_hflux_from_water_prec, fswabs_ai_m, sea_level_max, temp_xflux_submeso_int_z, tau_x, meltt, vvel_m, fswdn_m, tx_trans_rho_gm, NCAT, rain_ai_m, sfc_salt_flux_coupler, geolat_t, total_ocea...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle4</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 4/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1958-2019)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, 1yr, fx}</td>
#       <td>{psiu, sfc_hflux_from_water_prec, fswabs_ai_m, sea_level_max, temp_xflux_submeso_int_z, tau_x, meltt, vvel_m, fswdn_m, tx_trans_rho_gm, NCAT, rain_ai_m, sfc_salt_flux_coupler, geolat_t, total_ocea...</td>
#     </tr>
#     <tr>
#       <th>025deg_jra55_iaf_omip2_cycle5</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{Cycle 5/6 of 0.25 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.4 OMIP2 interannual forcing (1

# %%
# datastore_example = 
catalog.search(model="ACCESS-OM2", name="1deg_.*_ryf")#.to_source()
# Out:
# <p><strong>Intake dataframe catalog with 4 source(s) across 20 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>01deg_jra55v13_ryf9091</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{0.1 degree ACCESS-OM2 global model configuration with JRA55-do v1.3 RYF9091  repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, fx, 1day, 3mon, 3hr}</td>
#       <td>{tau_x, vvel_m, NCAT, frz_onset_m, sfc_salt_flux_coupler, geolat_t, total_ocean_runoff_heat, tx_trans_int_z, HTN, sst_m, surface_salt, dyu, tx_trans, uocn_m, temp_rivermix, passive_ross, eta_t, to...</td>
#     </tr>
#     <tr>
#       <th>1deg_era5_ryf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{1 degree ACCESS-OM2 global model configuration with ERA5 RYF9091 repeat\nyear forcing (May 1990 to Apr 1991)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{fswabs_ai_m, temp_xflux_submeso_int_z, tau_x, vvel_m, fswdn_m, NCAT, rain_ai_m, sfc_salt_flux_coupler, geolat_t, total_ocean_runoff_heat, tx_trans_int_z, HTN, surface_salt, dyu, strinty_m, surfac...</td>
#     </tr>
#     <tr>
#       <th>1deg_jra55_ryf9091_gadi</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{1 degree ACCESS-OM2 physics-only global configuration with JRA55-do v1.3 RYF9091 repeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1mon, 1yr, fx}</td>
#       <td>{temp_xflux_gm_on_nrho, fswabs_ai_m, tau_x, vvel_m, temp_vdiffuse_sbc_on_nrho, fswdn_m, NCAT, temp_vdiffuse_diff_cbt_kppicon_on_nrho, rain_ai_m, frz_onset_m, sfc_salt_flux_coupler, temp_yflux_gm, ...</td>
#     </tr>
#     <tr>
#       <th>1deg_jra55v14_ryf</th>
#       <td>{ACCESS-OM2}</td>
#       <td>{1 degree ACCESS-OM2 global model configuration with JRA55-do v1.4.0 RYF9091\nrepeat year forcing (May 1990 to Apr 1991)}</td>
#       <td>{seaIce, ocean}</td>
#       <td>{1day, 1mon, fx}</td>
#       <td>{fswabs_ai_m, temp_xflux_submeso_int_z, tau_x, vvel_m, fswdn_m, NCAT, rain_ai_m, sfc_salt_flux_coupler, geolat_t, total_ocean_runoff_heat, tx_trans_int_z, HTN, surface_salt, dyu, strinty_m, surfac...</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %%
datastore_example
# Out:
# <p><strong>by647 catalog with 7 dataset(s) from 1350 asset(s)</strong>:</p> <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>unique</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>path</th>
#       <td>1350</td>
#     </tr>
#     <tr>
#       <th>realm</th>
#       <td>3</td>
#     </tr>
#     <tr>
#       <th>variable</th>
#       <td>652</td>
#     </tr>
#     <tr>
#       <th>frequency</th>
#       <td>2</td>
#     </tr>
#     <tr>
#       <th>start_date</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>end_date</th>
#       <td>60</td>
#     </tr>
#     <tr>
#       <th>member</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>variable_long_name</th>
#       <td>643</td>
#     </tr>
#     <tr>
#       <th>variable_standard_name</th>
#       <td>135</td>
#     </tr>
#     <tr>
#       <th>variable_cell_methods</th>
#       <td>6</td>
#     </tr>
#     <tr>
#       <th>variable_units</th>
#       <td>92</td>
#     </tr>
#     <tr>
#       <th>filename</th>
#       <td>750</td>
#     </tr>
#     <tr>
#       <th>file_id</th>
#       <td>7</td>
#     </tr>
#     <tr>
#       <th>derived_variable</th>
#       <td>0</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
datastore_example.search(variable='aice', frequency='1mon').to_dask(
    xarray_combine_by_coords_kwargs={
                "compat": "override",
                "data_vars": "minimal",
                "coords": "minimal",
            })
# Out:
# <xarray.Dataset> Size: 131MB
# Dimensions:  (member: 5, time: 60, nj: 300, ni: 360)
# Coordinates:
#   * time     (time) datetime64[ns] 480B 2015-02-01 2015-03-01 ... 2020-01-01
#     TLON     (nj, ni) float32 432kB dask.array<chunksize=(300, 360), meta=np.ndarray>
#     TLAT     (nj, ni) float32 432kB dask.array<chunksize=(300, 360), meta=np.ndarray>
#     ULON     (nj, ni) float32 432kB dask.array<chunksize=(300, 360), meta=np.ndarray>
#     ULAT     (nj, ni) float32 432kB dask.array<chunksize=(300, 360), meta=np.ndarray>
#   * member   (member) object 40B 'by647' 'by647a' 'by647b' 'by647c' 'by647d'
# Dimensions without coordinates: nj, ni
# Data variables:
#     aice     (member, time, nj, ni) float32 130MB dask.array<chunksize=(1, 1, 300, 360), meta=np.ndarray>
# Attributes: (12/17)
#     title:                                    sea ice model output for CICE
#     contents:                                 Diagnostic and Prognostic Varia...
#     source:                                   Los Alamos Sea Ice Model (CICE)...
#     comment3:                                 seconds elapsed into model date...
#     conventions:                              CF-1.0
#     io_flavor:                                io_netcdf
#     ...                                       ...
#     intake_esm_attrs:variable_standard_name:  ,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,,...
#     intake_esm_attrs:variable_cell_methods:   ,,,,,,,,,,,,,time: mean,time: m...
#     intake_esm_attrs:variable_units:          days since 1850-01-01 00:00:00,...
#     intake_esm_attrs:file_id:                 iceh_m_XXXX_XX
#     intake_esm_attrs:_data_format_:           netcdf
#     intake_esm_dataset_key:                   iceh_m_XXXX_XX.1mon

# %% [markdown]
# # Additional source metadata

# %% [markdown]
# Each Intake-ESM datastore has its own `.metadata` attribute that contains additional information about that experiment.

# %%
catalog.by647.metadata
# Out:
# {'contact': 'Dave Bi',
#  'created': None,
#  'description': 'Standard CMIP6 ssp245 simulation, control experiment for by578 pacemaker experiment (1fd9e682-d393-4b17-a9cd-934c3a48a1f8)',
#  'email': 'dave.bi@csiro.au',
#  'experiment_uuid': '57243597-43c0-4a8f-a404-b10cecdeb3f7',
#  'keywords': [None],
#  'license': None,
#  'long_description': 'Standard CMIP6 ssp245 simulation with 5 ensemble members. Control experiment  for by578 pacemaker experiment (1fd9e682-d393-4b17-a9cd-934c3a48a1f8). Branched from parent experiment in 2015',
#  'model': ['ACCESS-CM2'],
#  'name': 'by647',
#  'nominal_resolution': ['atmos = n96', 'ocean = 1 degree'],
#  'notes': 'null',
#  'parent_experiment': '1c6e73fb-5380-43c1-8043-0526be2f1b8b',
#  'reference': None,
#  'related_experiments': ['1fd9e682-d393-4b17-a9cd-934c3a48a1f8'],
#  'url': None,
#  'version': 1,
#  'catalog_dir': ''}

# %% [markdown]
# # An example workflow
#
# (Note, up until this point we haven't actually opened any data from any products. However, below we access data from the `p73` project on Gadi. You will therefore need to be a member of this project to run this section.)
#
# As a full example workflow, let's use the ACCESS-NRI catalog to carry out a simple analysis comparing anomalies of the global average ocean surface temperature from four ACCESS-CM2 data products. First we'll search directly for the products by their names and see what each of them are.

# %%
catalog_filtered = catalog.search(name=["bx944", "by473", "by647", "by578"])

catalog_filtered
# Out:
# <p><strong>Intake dataframe catalog with 4 source(s) across 24 rows</strong>:</p> <div style='max-height: 300px; overflow: auto; width: fit-content'><div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>model</th>
#       <th>description</th>
#       <th>realm</th>
#       <th>frequency</th>
#       <th>variable</th>
#     </tr>
#     <tr>
#       <th>name</th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>bx944</th>
#       <td>{ACCESS-CM2}</td>
#       <td>{Standard CMIP6 historical simulation, control experiment for by473 pacemaker experiment (948d8676-2c56-49db-8ea1-b80572b074c8)}</td>
#       <td>{ocean, atmos, seaIce}</td>
#       <td>{1day, 1mon}</td>
#       <td>{snowfracn, fld_s03i807, temp_merid_flux_gyre_pacific, pbot_adjust, sitemptop, sithick, fld_s30i301, fld_s38i441, fld_s03i293, wind_power_v, river, potrho_mix_depth, psiu, fld_s02i261, total_ocean...</td>
#     </tr>
#     <tr>
#       <th>by473</th>
#       <td>{ACCESS-CM2}</td>
#       <td>{Pacemaker variation of CMIP6 historical simulation, Topical Atlantic region replaced  with fixed SSTs from observations}</td>
#       <td>{ocean, atmos, seaIce}</td>
#       <td>{1day, 1mon}</td>
#       <td>{snowfracn, fld_s03i807, temp_merid_flux_gyre_pacific, pbot_adjust, sitemptop, sithick, fld_s30i301, fld_s38i441, fld_s03i293, wind_power_v, river, potrho_mix_depth, psiu, fld_s02i261, total_ocean...</td>
#     </tr>
#     <tr>
#       <th>by578</th>
#       <td>{ACCESS-CM2}</td>
#       <td>{Pacemaker variation of CMIP6 ssp245 simulation with Tropical Atlantic region replaced  with fixed SSTs from observations}</td>
#       <td>{ocean, atmos, seaIce}</td>
#       <td>{1day, 1mon}</td>
#       <td>{snowfracn, fld_s03i807, temp_merid_flux_gyre_pacific, pbot_adjust, sitemptop, sithick, fld_s30i301, fld_s38i441, fld_s03i293, wind_power_v, river, potrho_mix_depth, psiu, fld_s02i261, total_ocean...</td>
#     </tr>
#     <tr>
#       <th>by647</th>
#       <td>{ACCESS-CM2}</td>
#       <td>{Standard CMIP6 ssp245 simulation, control experiment for by578 pacemaker experiment (1fd9e682-d393-4b17-a9cd-934c3a48a1f8)}</td>
#       <td>{ocean, atmos, seaIce}</td>
#       <td>{1day, 1mon}</td>
#       <td>{snowfracn, fld_s03i807, temp_merid_flux_gyre_pacific, pbot_adjust, sitemptop, sithick, fld_s30i301, fld_s38i441, fld_s03i293, wind_power_v, river, potrho_mix_depth, psiu, fld_s02i261, total_ocean...</td>
#     </tr>
#   </tbody>
# </table>
# </div></div>

# %% [markdown]
# Now we'll load the Intake-ESM datastores for those products using the `to_source_dict` method because there is more than one of them. This will take a few seconds.

# %%
datastore_dict = catalog_filtered.to_source_dict()

datastore_dict
# Out:
# {'bx944': <bx944 catalog with 7 dataset(s) from 12150 asset(s)>,
#  'by647': <by647 catalog with 7 dataset(s) from 1350 asset(s)>,
#  'by473': <by473 catalog with 7 dataset(s) from 12149 asset(s)>,
#  'by578': <by578 catalog with 7 dataset(s) from 1350 asset(s)>}

# %% [markdown]
# Now we can use our Intake-ESM datastores to open the data we want. You learned about Intake-ESM datastores earlier today. We'll show the basics here and refer to the Intake-ESM documentation [here](https://intake-esm.readthedocs.io/en/stable/index.html) for more information on how to use Intake-ESM datastores.
#
# We're going to use dask to help us open and process the data from these datastores. We can start a local distributed dask cluster as follows.

# %%
from distributed import Client

client = Client(threads_per_worker=1)

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:43001' processes=12 threads=12, memory=46.00 GiB>

# %% [markdown]
# Note, it is very helpful to monitor the dask dashboard when working with dask. Click on the dask icon on the far left of the screen (three orange and red squares) and enter the text output by the previous cell in the search bar. Each of the different orange panels is a different dashboard that you can use to monitor what dask is doing. If you don't know which to choose, the "Task Stream", "Progress", "CPU" and "Workers Memory" diagnostics are a good start. Click on these, and drag the windows to where ever you want them in your JupyterLab.

# %% [markdown]
# In these ACCESS-CM2 products, monthly global average ocean surface temperatures are available in the variable `temp_surface_ave`. We can open an xarray Dataset with `temp_surface_ave` from the Intake-ESM datastore for each product as follows. The opening of these files will be parallelized across our dask cluster - watch you dask dashboard when you execute the following cell. Note that, because the datasets here are small, we've chosen to load them immediately using `load()`.

# %%
dataset_dict = {
    name: datastore.search(variable="temp_surface_ave").to_dask().load()
    for name, datastore in datastore_dict.items()
}

# %% [markdown]
# The following function will calculate the anomalies of a provided dataset relative to the climatological mean of another dataset over the period 1971-2000. Here we'll calculate the anomalies for each product relative to the "bx944" standard historical run.

# %%
def anomalize(dataset, dataset_baseline, period=slice("1971","2000")):
    """
    Calculate the anomalies of ds relative to the climatological mean of ds_baseline over period
    """
    clim = dataset_baseline.sel(time=period).mean("member").groupby("time.month").mean("time")
    return dataset.groupby("time.month") - clim

# %%
anomalies_dict = {
    name: anomalize(dataset, dataset_dict["bx944"]) for name, dataset in dataset_dict.items()
}
# Out:
# INFO:flox:Entering _validate_reindex: reindex is None
# INFO:flox:Leaving _validate_reindex: method = None, returning None
# INFO:flox:_choose_engine: Choosing 'numpy'
# INFO:flox:Entering _validate_reindex: reindex is None
# INFO:flox:Leaving _validate_reindex: method = None, returning None
# INFO:flox:_choose_engine: Choosing 'numpy'
# INFO:flox:Entering _validate_reindex: reindex is None
# INFO:flox:Leaving _validate_reindex: method = None, returning None
# INFO:flox:_choose_engine: Choosing 'numpy'
# INFO:flox:Entering _validate_reindex: reindex is None
# INFO:flox:Leaving _validate_reindex: method = None, returning None
# INFO:flox:_choose_engine: Choosing 'numpy'

# %% [markdown]
# To plot our data, we'll use a simple function that receives our dictionary of anomalies and plots the timeseries

# %%
import matplotlib.pyplot as plt
from datetime import datetime

def plot_temp_surface_ave(dataset_dict):
    for idx, (name, ds) in enumerate(dataset_dict.items()):
        data = ds["temp_surface_ave"].squeeze()
        data.plot.line(x="time", color=f"C{idx}", add_legend=False, label=name)
    
    plt.title("Global mean ocean surface temperature")
    plt.grid()
    plt.xlim([datetime(1969,1,1), datetime(2020,12,31)])
    
    # Add legend, removing duplicates due to multiple members
    handles, labels = plt.gca().get_legend_handles_labels()
    by_label = dict(zip(labels, handles))
    plt.legend(by_label.values(), by_label.keys())

# %%
plot_temp_surface_ave(anomalies_dict)

# %% [markdown]
# Maybe we'd also like to add some CMIP6 ACCESS-CM2 data to our plot? That's easy because the [NCI CMIP Intake-ESM datastores](https://opus.nci.org.au/pages/viewpage.action?pageId=213713098) are included in the ACCESS-NRI catalog.

# %%
cmip6_datastore = catalog.search(name="cmip6.*", model="ACCESS-ESM1-5").to_source()

# %% [markdown]
# In this case however, there's no variable for global average ocean surface temperatures, so we'll have to calculate the area-weighted average ourselves from fields of ocean surface temperature.

# %%
tos_dataset = cmip6_datastore.search(
    source_id="ACCESS-CM2", 
    table_id="Omon", 
    variable_id="tos", 
    experiment_id="historical", 
    member_id="r1i1p1f1",
    file_type="f"
).to_dask()

area_dataset = cmip6_datastore.search(
    source_id="ACCESS-CM2", 
    table_id="Ofx", 
    variable_id="areacello", 
    experiment_id="historical", 
    member_id="r1i1p1f1",
    file_type="f"
).to_dask()

temp_surface_ave = tos_dataset["tos"].weighted(area_dataset["areacello"]).mean(["i", "j"]).to_dataset(name="temp_surface_ave").load()

# %% [markdown]
# Again, we'll compute the anomalies relative to the "bx944" data for consistency and add this to our dictionary of anomalies to pass on to our plotting function.

# %%
anomalies_dict["ACCESS-CM2 historical r1i1p1f1"] = anomalize(temp_surface_ave, dataset_dict["bx944"])
# Out:
# INFO:flox:Entering _validate_reindex: reindex is None
# INFO:flox:Leaving _validate_reindex: method = None, returning None
# INFO:flox:_choose_engine: Choosing 'numpy'

# %%
plot_temp_surface_ave(anomalies_dict)

# %% [markdown]
# ## Challenge yourself
#
# Can you add a CMIP6 ACCESS-CM2 SSP245 member to the plot?
#
# Hint: CMIP6 experiments of the [SSP245 pathway](https://www.dkrz.de/en/communication/climate-simulations/cmip6-en/the-ssp-scenarios) have the `experiment_id = "ssp245"`

# %%
client.close()
